# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
tickersMDax = pd.read_html("https://en.wikipedia.org/wiki/MDAX")[1].Symbol.to_list()
tickersMDax = [str(ticker)+".DE" for ticker in tickersMDax]

data = []
tickersNew = []
for ticker in tickersMDax:
    if len(yf.download(ticker)) < 1000:
        continue
    else:
        tickersNew.append(ticker)
        
downloaded = yf.download(tickersNew, start=('2013-08-01'))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
# out = {}

# for k in tqdm(np.linspace(0.5, 0.9, 5)):

k = float(0.7)

output = pd.DataFrame(index=np.linspace(20, 240, 12), columns=np.linspace(20, 240, 12))
extra = []

a = 0
for i in np.linspace(20, 240, 12): #days for momentum check
    b = 0 
    for j in np.linspace(20, 240, 12): #days for return
        days = int(i)
        j = int(j)

        days_end = (j+1)*-1

        length = len(price.columns)
#     get amount of companies/ length of df 

        price = downloaded['Adj Close']
#     get only adj.close

        return_ = price.apply(lambda x: np.log(x.shift(-j)/x.shift(-1))*(1/(j/240)), axis=0).iloc[days:days_end]
#     calculate future return based on j 

        pre_return = price.apply(lambda x: (np.log(x.shift(0)/x.shift(days))-1).rolling(10).mean()+(np.log(x.shift(0)/x.shift(days-20))-1).rolling(10).mean()+(np.log(x.shift(0)/x.shift(days+20))-1).rolling(10).mean(), axis=0).iloc[days:days_end]
#     calculate previous return for momentum 

        price = price.iloc[days:days_end]
#     decrease price to be same size as other

        rank = pre_return.apply(lambda x: (x.rank(axis=0)/length), axis=1)
#     rank based on momentum

        buy = rank.apply(lambda x: x > k , axis=0)
#     buy all with rank above 0.8

        dates_month = pd.bdate_range(buy.index.min(), buy.index.max(), freq='1M')
        buy = buy[buy.index.isin(dates_month)]


        scoreb = buy.mul(return_).replace(0, np.NaN).mean().mean()

        score = return_.mean().mean()
        output.iloc[a,b] = scoreb
        extra.append(score)
        b+=1
    a +=1
average = sum(extra)/len(extra)
#     maximum = output.values.max()
#     out[k] = maximum

# %%
output.to_excel('Output3000days0-7_new.xlsx')

# %%
out
# Out:
# {0.5: 0.15297239845161928,
#  0.6: 0.17924990992357123,
#  0.7: 0.17525153171156013,
#  0.8: 0.23209897735935056,
#  0.9: 0.2982876883348622}

# %%
days = 160

tickersMDax = pd.read_html("https://en.wikipedia.org/wiki/MDAX")[1].Symbol.to_list()
tickersMDax = [str(ticker)+".DE" for ticker in tickersMDax]

data = []
tickersNew = []
for ticker in tickersMDax:
    if len(yf.download(ticker)) < 500:
        continue
    else:
        tickersNew.append(ticker)
        
downloaded = yf.download(tickersNew, start=('2013-08-01'))


price = downloaded['Adj Close']
#     get only adj.close

length = len(price.columns)
#     get amount of companies/ length of df 

pre_return = price.apply(lambda x: ((np.log(x.shift(0)/x.shift(days))-1) + (np.log(x.shift(0)/x.shift(days))-1) + (np.log(x.shift(0)/x.shift(days))-1)).rolling(10).mean(), axis=0).iloc[-160:-1]
#     calculate previous return for momentum 

price = price.iloc[-160:-1]
#     decrease price to be same size as other

rank = pre_return.apply(lambda x: (x.rank(axis=0)/length), axis=1)
#     rank based on momentum

buy = rank.apply(lambda x: x > 0.8 , axis=0)


        
non_buy_list = []
for i in range(len(buy.columns)):
    if buy.iloc[-1,i]:
        continue
    else:
        non_buy_list.append((buy.columns[i], price[price.columns[i]]))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
plt.figure(figsize=(18, 6))
for (i, j) in buy_list: 
    j = j/j[0]
    plt.plot(j.index, j)

# %%
plt.figure(figsize=(18, 6))
for (i, j) in non_buy_list: 
    j = j/j[0]
    plt.plot(j.index, j)

# %%
out[1] = 2

# %%
# Out:
# {0.9: 240.0, 1: 2}

# %%
price = downloaded['Adj Close']

# %%
# Out:
# AFX.DE
# 186.6999969482422
# 1
# AIXA.DE
# 22.8700008392334
# 9
# B4B.DE
# 11.484999656677246
# 18
# BNR.DE
# 86.0199966430664
# 2
# BOSS.DE
# 52.65999984741211
# 4
# EVT.DE
# 41.599998474121094
# 5
# G1A.DE
# 38.45000076293945
# 5
# SDF.DE
# 11.819999694824219
# 17
# SHL.DE
# 59.459999084472656
# 3
# SRT.DE
# 602.0
# 0
# VAR1.DE
# 136.1999969482422
# 1

# %%
7000/3
# Out:
# 2333.3333333333335
